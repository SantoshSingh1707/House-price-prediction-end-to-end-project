# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/14.8 MB 1.6 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/14.8 MB 1.7 MB/s eta 0:00:09
#       --------------------------------------- 0.2/14.8 MB 2.3 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/14.8 MB 3.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/14.8 MB 3.6 MB/s eta 0:00:04
#      -- ------------------------------------- 1.0/14.8 MB 4.1 MB/s eta 0:00:04
#      --- ------------------------------------ 1.2/14.8 MB 4.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/14.8 MB 4.9 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.9/14.8 MB 5.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.9/14.8 MB 5.6 MB/s eta 0:00:03
#      ------ --------------------------------- 2.3/14.8 MB 5.2 MB/s eta 0:00:03
# ...

# %%
pip install zenml
